# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
import sklearn.metrics as skm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Gerando dados

# %%
samples = 1000
X = np.linspace(1.0, 20.0, samples)[:, np.newaxis]
Y = (2.35 * X + 6.21) + (np.random.randn(samples, 1) * 10)
YY = (2.35 * X + 6.21)

# %% [markdown]
# - Separando os dados

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=13)

# %% [markdown]
# ## Plotando

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.plot(X, YY, color="r", label="Distribuição", linewidth=3)
ax.scatter(X_train, y_train, color="b", label="Treino")
ax.scatter(X_test, y_test, color="gold", label="Teste")
ax.legend()

# %% [markdown]
# # Usando o modelo linear

# %% [markdown]
# ## `LinearRegression()`
# - [Documentação](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression)

# %% [markdown]
# - Treinando o modelo

# %%
model_1 = linear_model.SGDRegressor(verbose=True)
model_1.fit(X_train, y_train.ravel())
# Out:
# -- Epoch 1
# Norm: 2.18, NNZs: 1, Bias: 2.032166, T: 700, Avg. loss: 67.969384
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 2.49, NNZs: 1, Bias: 2.957519, T: 1400, Avg. loss: 58.440389
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 2.89, NNZs: 1, Bias: 3.496400, T: 2100, Avg. loss: 54.107682
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 2.52, NNZs: 1, Bias: 3.902964, T: 2800, Avg. loss: 56.217327
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 2.39, NNZs: 1, Bias: 4.209987, T: 3500, Avg. loss: 55.744363
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 2.66, NNZs: 1, Bias: 4.491625, T: 4200, Avg. loss: 55.001729
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 2.35, NNZs: 1, Bias: 4.686729, T: 4900, Avg. loss: 54.838576
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 2.04, NNZs: 1, Bias: 4.880364, T: 5600, Avg. loss: 55.740298
# Total training time: 0.00 seconds.
# Convergence after 8 epochs took 0.00 seconds
# SGDRegressor(verbose=True)

# %% [markdown]
# - Visualizando o valor dos pesos treinados

# %%
print("Pesos:", model_1.coef_)
print("Bias:", model_1.intercept_)
# Out:
# Pesos: [2.03611692]
# Bias: [4.88036435]

# %% [markdown]
# - Realizando a predição do conjunto de teste

# %%
preds = model_1.predict(X_test)

# %% [markdown]
# - Verificando o MSE

# %%
mse = skm.mean_squared_error(y_test, preds)
print("MSE:", mse)
# Out:
# MSE: 140.56915206153397

# %% [markdown]
# - Plotando:

# %%
ax.plot(X_test, preds, color="lime", label="SGD", linewidth=2)
ax.legend()
fig

# %% [markdown]
# ___
# # Exercício
# - Execute outros modelos lineares, faça o plot da curva e compare as métricas entre eles
# ___

# %%
model_2 = linear_model.LinearRegression()
model_2.fit(X_train, y_train.ravel())
# Out:
# LinearRegression()

# %%
print("Pesos:", model_2.coef_)
print("Bias:", model_2.intercept_)
# Out:
# Pesos: [2.29547297]
# Bias: 5.763679256441286

# %%
y_pred = model_2.predict(X_test)
mse2 = skm.mean_squared_error(y_test, y_pred)
print("MSE:", mse)
# Out:
# MSE: 140.56915206153397

# %%
ax.plot(X_test, y_pred, color="orange", label="Regressao Linear", linewidth=2)
ax.legend()
fig
